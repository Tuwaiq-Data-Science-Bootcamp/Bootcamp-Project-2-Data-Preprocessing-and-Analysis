# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import pie, axis, show
# %matplotlib inline
import seaborn as sns

# %%
df= pd.read_csv("country_wise_latest.csv")
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %% [markdown]
# ## EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
df.shape
# Out:
# (187, 15)

# %%
df.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# ...

# %%
df.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
df.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
df.tail()
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 182           2              0                0.73                  35.33
# 183           0              0               10.00                  80.00
# 184           4             36               28.56                  49.26
# 185           1            465                3.08                  61.84
# 186           2             24                1.33                  20.04
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
#Rename th columns
df.rename( columns = {'Country/Region':'Country','WHO Region':'Region'},inplace = True)

# %% [markdown]
# ## Data Visualization

# %%
#Confirmed_cases_per_Region

#Confirmed_cases= df.groupby(by='WHO Region').max()[['Confirmed']].sort_values(by ='Confirmed',ascending =False).reset_index()
Confirmed_cases= df.groupby(by='Region')['Confirmed'].sum().sort_values(ascending =False)

Confirmed_cases.plot.pie(title='Confirmed cases',colors = palette);
#plt.legend(['Confirmed cases','Region'], shadow = True, loc = 0);
plt.xlabel('Region')
plt.ylabel('Confirmed cases')
# Out:
# Text(0, 0.5, 'Confirmed cases')

# %%
# top 10 actave cases 
top_10_active= df.groupby(by='Region').max()[['Active']].sort_values(by = 'Active',ascending =False).reset_index()
fig= plt.figure(figsize=(20,10))
plt.title('top 5 actave cases in 2020 per Region',color='black',size=25)
sns.barplot(data= top_10_active.iloc[:5],y='Active', x='Region',hue="Active",linewidth=2, edgecolor='black')
plt.xlabel('Region')
plt.ylabel('Active cases')
plt.grid()
plt.show()

# %%
# top Region with highest deaths
top_10_active= df.groupby(by='Region').max()[['Deaths']].sort_values(by = 'Deaths',ascending =False).reset_index()
fig= plt.figure(figsize=(20,10))
plt.title('top Region with highest deaths',color='black',size=14)
sns.barplot(data= top_10_active.iloc[:5],y='Deaths', x='Region',linewidth=1, edgecolor='black',hue="Deaths",palette='coolwarm')
plt.xlabel('Region')
plt.ylabel('Death cases')
plt.show()

# %%
#The rate of recovery by Region
#df2= df.groupby('WHO Region')['Recovered'].sum().sort_values(ascending =False)
plt.figure(figsize=(20,10))
sns.kdeplot(data=df,x='Recovered',hue='Region',palette='coolwarm')
#plt.legend(['New cases','Country'], shadow = True, loc = 0);
plt.title('The rate of recovery by Region ', size=14)
# Out:
# Text(0.5, 1.0, 'The rate of recovery by Region ')

# %%
df1 = df[df['Region'] == 'Eastern Mediterranean']
df1
# Out:
#                   country  Confirmed  Deaths  Recovered  Active  New cases  \
# 0             Afghanistan      36263    1269      25198    9796        106
# 12                Bahrain      39482     141      36110    3231        351
# 48               Djibouti       5059      58       4977      24          9
# 52                  Egypt      92482    4652      34838   52992        420
# 81                   Iran     293606   15912     255144   22550       2434
# 82                   Iraq     112585    4458      77144   30983       2553
# 88                 Jordan       1176      11       1041     124          8
# 92                 Kuwait      64379     438      55057    8884        606
# 96                Lebanon       3882      51       1709    2122        132
# 99                  Libya       2827      64        577    2186        158
# 116               Morocco      20887     316      16553    4018        609
# ...

# %%
top_actives=df1.groupby("country")["New cases"].sum().sort_values(ascending=False).head(10).reset_index()


plt.figure(figsize=(10,4))
plt.scatter(x="country",y="New cases",data= top_actives,alpha = 0.5, c= palette1);
#plt.legend(['New cases','Country'], shadow = True, loc = 0);
plt.xlabel('Country')
plt.ylabel('New cases')
plt.title('a ', size=14)
# Out:
# Text(0.5, 1.0, 'top 10 countries with highest New cases ')

# %%
top_actives1=df1.groupby("country")["Deaths"].sum().sort_values(ascending=False).head(10).reset_index()

plt.figure(figsize=(12,4)) 

sns.swarmplot(
    x="country",
    y="Deaths",  
    data=top_actives1,
    hue="Deaths",
    palette='coolwarm'
)
plt.title('top 10 Country with highest Deaths cases ', size=14);

# %%
top_actives2=df1.groupby("country")["Recovered"].sum().sort_values(ascending=False).head(10).reset_index()

plt.figure(figsize=(15,4))
plt.plot(top_actives2['country'],top_actives2['Recovered'],color= palette[0]);
plt.legend(['Recovered','Country'], shadow = True, loc = 0);
plt.xlabel('Country')
plt.ylabel('Recovered cases')
plt.title('top 10 countries with highest Recovered cases', size=14)
# Out:
# Text(0.5, 1.0, 'top 10 countries with highest Recovered cases')

# %%
top_actives3=df1.groupby("country")["Active"].sum().sort_values(ascending=False).head(10).reset_index()

plt.figure(figsize=(20,5))
plt.bar(top_actives3['country'],top_actives3['Active'],color = palette);
#plt.legend(['Active','Country'], shadow = True, loc = 0);
plt.xlabel('Country')
plt.ylabel('Active cases')
plt.title('top 10 countries with highest Active cases', size=14);

# %%
sns.relplot(x="Confirmed", y="Recovered", alpha=.8,hue="Confirmed", palette='coolwarm',height=3, data=df1);
#plt.legend(['Confirmed cases','Recovered'], shadow = True, loc = 0);
plt.title('Relational between Recovered cases and Confirmed cases ', size=10);

# %%
top_actives4=df1.groupby("country")["Confirmed"].sum().sort_values(ascending=False).head(10).reset_index()
sums = top_actives4.groupby(top_actives4["country"])["Confirmed"].sum()
axis('equal');

pie(sums, labels=sums.index,autopct='%1.0f%%',colors = palette);
#plt.legend(['New cases','Country'], shadow = True, loc = 0);
xl= plt.xlabel('New cases');
plt.ylabel('Country')
plt.title('top 10 countries with highest Confirmed cases', size=14);
show()

# %%
plt.figure(figsize=[25,25])
plt.suptitle('Covid-19 Charts',fontsize = 27)

palett='coolwarm'
palette= sns.color_palette('coolwarm')
palette1 = np.random.randint(10, size=(10))

plt.subplot(4,3,1)
pie(sums, labels=sums.index,autopct='%1.0f%%',colors = palette);
#plt.legend(['New cases','Country'], shadow = True, loc = 0);
xl= plt.xlabel('New cases');
plt.ylabel('Country')
plt.title('top 10 countries with highest Confirmed cases', size=14);

plt.subplot(4,3,2)
plt.bar(top_actives3['country'],top_actives3['Active'],color = palette);
#plt.legend(['Active','Country'], shadow = True, loc = 0);
plt.xlabel('Country')
plt.ylabel('Active cases')
plt.title('top 10 countries with highest Active cases', size=14);

plt.subplot(4,3,3)
plt.plot(top_actives2['country'],top_actives2['Recovered'],color= palette[0]);
plt.legend(['Recovered','Country'], shadow = True, loc = 0);
plt.xlabel('Country')
plt.ylabel('Recovered cases')
plt.title('top 10 countries with highest Recovered cases', size=14)

plt.subplot(4,3,4)
plt.scatter(x="country",y="New cases",data= top_actives,alpha = 0.5, c= palette1);
#plt.legend(['New cases','Country'], shadow = True, loc = 0);
plt.xlabel('Country')
plt.ylabel('New cases')
plt.title('top 10 countries with highest New cases ', size=14)

plt.subplot(4,3,5)
sns.kdeplot(data=df,x='Recovered',hue='Region',palette='coolwarm')
#plt.legend(['New cases','Country'], shadow = True, loc = 0);
plt.title('The rate of recovery by Region ', size=14)

plt.subplot(4,3,6)
Confirmed_cases.plot.pie(title='Confirmed cases',colors = palette);
#plt.legend(['Confirmed cases','Region'], shadow = True, loc = 0);
plt.xlabel('Region')
plt.ylabel('Confirmed cases')
plt.title('Confirmed cases', size=14)


plt.subplot(4,3,7)
sns.barplot(data= top_10_active.iloc[:5],y='Deaths', x='Region',linewidth=1, edgecolor='black',hue="Deaths",palette='coolwarm')
plt.title('top Region with highest deaths', size=14)

plt.subplot(4,3,8)
sns.swarmplot(
    x="country",
    y="Deaths",  
    data=top_actives1,
    hue="Deaths",
    palette='coolwarm'
)
plt.title('top 10 Country with highest Deaths cases ', size=14)

plt.subplot(4,3,9)
#sns.barplot(data= top_10_active.iloc[:5],y='Active', x='WHO Region',hue="Active",linewidth=2, edgecolor='black')
plt.xlabel('Region')
plt.ylabel('Active cases')
plt.title('top 5 actave cases in 2020 per Region',color='black',size=14)
plt.grid()

plt.subplot(4,3,10)
sns.relplot(x="Confirmed", y="Recovered", alpha=.8,hue="Confirmed", palette='coolwarm',height=3, data=df1);
#plt.legend(['Confirmed cases','Recovered'], shadow = True, loc = 0);
plt.title('Relational between Recovered cases and Confirmed cases ', size=10);
